# %%
import numpy as np
import pandas as pd

from sklearn.metrics import mean_squared_error, r2_score
from catboost import CatBoostRegressor
from xgboost import XGBRegressor

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import RootMeanSquaredError

import keras_tuner as kt

# %%
train = pd.read_csv("../artifacts/data_transformation/train.csv")
test = pd.read_csv("../artifacts/data_transformation/test.csv")

X_train = train.drop(columns = "Listening_Time_minutes")
y_train = train["Listening_Time_minutes"]

X_test = test.drop(columns = "Listening_Time_minutes")
y_test = test["Listening_Time_minutes"]

# %% [markdown]
# ## Catboost Model

# %%
cat_model = CatBoostRegressor(
    iterations=1000,
    learning_rate=0.1,
    depth=6,
    random_seed=42,
    eval_metric="RMSE",
    use_best_model=True,
    verbose=10
)

cat_model.fit(
    X_train, y_train,
    eval_set=(X_test, y_test),
    early_stopping_rounds=50
)
# Out:
# 0:	learn: 25.1823205	test: 25.4269461	best: 25.4269461 (0)	total: 172ms	remaining: 2m 52s
# 10:	learn: 15.8471974	test: 16.1457308	best: 16.1457308 (10)	total: 315ms	remaining: 28.3s
# 20:	learn: 13.9632069	test: 14.2776942	best: 14.2776942 (20)	total: 454ms	remaining: 21.2s
# 30:	learn: 13.6226223	test: 13.9376083	best: 13.9376083 (30)	total: 591ms	remaining: 18.5s
# 40:	learn: 13.5392980	test: 13.8642984	best: 13.8642984 (40)	total: 714ms	remaining: 16.7s
# 50:	learn: 13.4939599	test: 13.8393509	best: 13.8393509 (50)	total: 840ms	remaining: 15.6s
# 60:	learn: 13.4667935	test: 13.8275968	best: 13.8275968 (60)	total: 971ms	remaining: 14.9s
# 70:	learn: 13.4392635	test: 13.8234380	best: 13.8234380 (70)	total: 1.13s	remaining: 14.8s
# 80:	learn: 13.4149752	test: 13.8190967	best: 13.8190967 (80)	total: 1.25s	remaining: 14.1s
# 90:	learn: 13.3904706	test: 13.8148485	best: 13.8148485 (90)	total: 1.36s	remaining: 13.6s
# 100:	learn: 13.3682651	test: 13.8120494	best: 13.8109321 (98)	total: 1.48s	remaining: 13.2s
# 110:	learn: 13.3481576	test: 13.8091153	best: 13.8091153 (110)	total: 1.63s	remaining: 13s
# 120:	learn: 13.3226180	test: 13.8072004	best: 13.8060449 (114)	total: 1.75s	remaining: 12.7s
# 130:	learn: 13.2996299	test: 13.8050232	best: 13.8050232 (130)	total: 1.87s	remaining: 12.4s
# 140:	learn: 13.2754736	test: 13.8074677	best: 13.8049870 (132)	total: 2.01s	remaining: 12.2s
# 150:	learn: 13.2498774	test: 13.8080592	best: 13.8049870 (132)	total: 2.14s	remaining: 12s
# 160:	learn: 13.2232351	test: 13.8102527	best: 13.8049870 (132)	total: 2.27s	remaining: 11.8s
# 170:	learn: 13.2005926	test: 13.8102260	best: 13.8049870 (132)	total: 2.38s	remaining: 11.6s
# 180:	learn: 13.1735149	test: 13.8117760	best: 13.8049870 (132)	total: 2.54s	remaining: 11.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 13.80498704
# bestIteration = 132
#
# Shrink model to first 133 iterations.

# %%
# Validation
predictions = cat_model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
r2 = r2_score(y_test, predictions)
print(f"CatBoost RMSE: {rmse}")
print(f"CatBoost R2: {r2}")
# Out:
# CatBoost RMSE: 13.804987040030186
# CatBoost R2: 0.7449047199293921

# %% [markdown]
# ## XG Boost

# %%
xgb_model = XGBRegressor(
    n_estimators=1000,
    learning_rate=0.1,
    max_depth=6,
    random_state=42,
    early_stopping_rounds=50,
    eval_metric="rmse"
)

xgb_model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=10
)
# Out:
# [0]	validation_0-rmse:25.34840
# [10]	validation_0-rmse:15.74967
# [20]	validation_0-rmse:14.10290
# [30]	validation_0-rmse:13.88458
# [40]	validation_0-rmse:13.86473
# [50]	validation_0-rmse:13.88280
# [60]	validation_0-rmse:13.89142
# [70]	validation_0-rmse:13.90377
# [80]	validation_0-rmse:13.91425
# [88]	validation_0-rmse:13.91613
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Validation
predictions = xgb_model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
r2 = r2_score(y_test, predictions)
print(f"CatBoost RMSE: {rmse}")
print(f"CatBoost R2: {r2}")
# Out:
# CatBoost RMSE: 13.85779393417628
# CatBoost R2: 0.7429494042637145

# %% [markdown]
# ## Artificial Neural Networks

# %%
model = Sequential([
    Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='relu'),
    Dropout(0.2),
    Dense(1)
])
# Out:
# c:\Users\kisho\anaconda3\envs\podacast\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 256)            │         4,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │           650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 46,677 (182.33 KB)
#  Trainable params: 46,677 (182.33 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
optimizer = Adam(learning_rate = 0.01)

model.compile(
    optimizer=optimizer,
    loss='mean_squared_error',
    metrics=['RootMeanSquaredError']
)

# Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train, y_train,
    batch_size = 256,
    validation_data=(X_test, y_test),
    epochs=100,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - RootMeanSquaredError: 26.2354 - loss: 710.5206 - val_RootMeanSquaredError: 15.1378 - val_loss: 229.1530
# Epoch 2/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - RootMeanSquaredError: 19.0436 - loss: 362.6822 - val_RootMeanSquaredError: 14.1425 - val_loss: 200.0101
# Epoch 3/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - RootMeanSquaredError: 18.4157 - loss: 339.1650 - val_RootMeanSquaredError: 14.1669 - val_loss: 200.6998
# Epoch 4/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 18.3810 - loss: 337.8829 - val_RootMeanSquaredError: 15.9049 - val_loss: 252.9657
# Epoch 5/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 18.3515 - loss: 336.7934 - val_RootMeanSquaredError: 13.9925 - val_loss: 195.7887
# Epoch 6/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 18.1018 - loss: 327.6894 - val_RootMeanSquaredError: 14.0469 - val_loss: 197.3142
# Epoch 7/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 18.2593 - loss: 333.4149 - val_RootMeanSquaredError: 14.2566 - val_loss: 203.2504
# Epoch 8/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - RootMeanSquaredError: 18.0920 - loss: 327.3451 - val_RootMeanSquaredError: 14.0010 - val_loss: 196.0267
# Epoch 9/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 17.7093 - loss: 313.6318 - val_RootMeanSquaredError: 14.5861 - val_loss: 212.7530
# Epoch 10/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 17.6439 - loss: 311.4259 - val_RootMeanSquaredError: 14.1185 - val_loss: 199.3322
# Epoch 11/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 17.5772 - loss: 308.9812 - val_RootMeanSquaredError: 14.7231 - val_loss: 216.7708
# Epoch 12/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - RootMeanSquaredError: 17.3471 - loss: 301.0049 - val_RootMeanSquaredError: 14.2197 - val_loss: 202.2002
# Epoch 13/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 17.3464 - loss: 300.9455 - val_RootMeanSquaredError: 15.4888 - val_loss: 239.9033
# Epoch 14/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 17.1527 - loss: 294.2623 - val_RootMeanSquaredError: 14.0191 - val_loss: 196.5365
# Epoch 15/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 17.1288 - loss: 293.4515 - val_RootMeanSquaredError: 14.4535 - val_loss: 208.9042
# Epoch 16/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 17.0167 - loss: 289.7002 - val_RootMeanSquaredError: 13.9757 - val_loss: 195.3189
# Epoch 17/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - RootMeanSquaredError: 17.0541 - loss: 290.8723 - val_RootMeanSquaredError: 14.2443 - val_loss: 202.9002
# Epoch 18/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 16.7760 - loss: 281.4685 - val_RootMeanSquaredError: 14.1253 - val_loss: 199.5252
# Epoch 19/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - RootMeanSquaredError: 16.7085 - loss: 279.1818 - val_RootMeanSquaredError: 14.5533 - val_loss: 211.7972
# Epoch 20/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - RootMeanSquaredError: 16.5365 - loss: 273.4938 - val_RootMeanSquaredError: 14.0223 - val_loss: 196.6262
# Epoch 21/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 16.5943 - loss: 275.3783 - val_RootMeanSquaredError: 14.3358 - val_loss: 205.5138
# Epoch 22/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 16.5587 - loss: 274.2097 - val_RootMeanSquaredError: 14.0387 - val_loss: 197.0843
# Epoch 23/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - RootMeanSquaredError: 16.6160 - loss: 276.1369 - val_RootMeanSquaredError: 13.9393 - val_loss: 194.3053
# Epoch 24/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 16.2720 - loss: 264.7920 - val_RootMeanSquaredError: 15.5446 - val_loss: 241.6355
# Epoch 25/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - RootMeanSquaredError: 16.3954 - loss: 268.8381 - val_RootMeanSquaredError: 14.1144 - val_loss: 199.2153
# Epoch 26/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - RootMeanSquaredError: 16.2294 - loss: 263.4058 - val_RootMeanSquaredError: 15.9144 - val_loss: 253.2677
# Epoch 27/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 16.4087 - loss: 269.3346 - val_RootMeanSquaredError: 13.9948 - val_loss: 195.8535
# Epoch 28/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 16.2239 - loss: 263.2281 - val_RootMeanSquaredError: 13.9950 - val_loss: 195.8603
# Epoch 29/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - RootMeanSquaredError: 16.0414 - loss: 257.3653 - val_RootMeanSquaredError: 14.0440 - val_loss: 197.2327
# Epoch 30/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - RootMeanSquaredError: 16.0479 - loss: 257.5400 - val_RootMeanSquaredError: 14.2574 - val_loss: 203.2733
# Epoch 31/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.9846 - loss: 255.5312 - val_RootMeanSquaredError: 13.9846 - val_loss: 195.5703
# Epoch 32/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.7490 - loss: 248.0528 - val_RootMeanSquaredError: 14.0728 - val_loss: 198.0432
# Epoch 33/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - RootMeanSquaredError: 16.0159 - loss: 256.5201 - val_RootMeanSquaredError: 14.0281 - val_loss: 196.7868
# Epoch 34/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.8926 - loss: 252.6143 - val_RootMeanSquaredError: 14.4608 - val_loss: 209.1149
# Epoch 35/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.7548 - loss: 248.2245 - val_RootMeanSquaredError: 14.0008 - val_loss: 196.0218
# Epoch 36/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.9454 - loss: 254.2931 - val_RootMeanSquaredError: 14.5371 - val_loss: 211.3263
# Epoch 37/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.7476 - loss: 248.0135 - val_RootMeanSquaredError: 14.1743 - val_loss: 200.9099
# Epoch 38/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - RootMeanSquaredError: 15.8106 - loss: 250.0004 - val_RootMeanSquaredError: 14.0944 - val_loss: 198.6528
# Epoch 39/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - RootMeanSquaredError: 15.8815 - loss: 252.2307 - val_RootMeanSquaredError: 14.2527 - val_loss: 203.1407
# Epoch 40/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - RootMeanSquaredError: 15.6950 - loss: 246.3486 - val_RootMeanSquaredError: 14.3033 - val_loss: 204.5838
# Epoch 41/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - RootMeanSquaredError: 15.7945 - loss: 249.4807 - val_RootMeanSquaredError: 13.9891 - val_loss: 195.6954
# Epoch 42/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.8313 - loss: 250.6376 - val_RootMeanSquaredError: 14.4594 - val_loss: 209.0749
# Epoch 43/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.7408 - loss: 247.7937 - val_RootMeanSquaredError: 14.0374 - val_loss: 197.0476
# Epoch 44/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - RootMeanSquaredError: 15.6294 - loss: 244.2995 - val_RootMeanSquaredError: 14.2581 - val_loss: 203.2941
# Epoch 45/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.6273 - loss: 244.2276 - val_RootMeanSquaredError: 14.6669 - val_loss: 215.1183
# Epoch 46/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.5783 - loss: 242.7048 - val_RootMeanSquaredError: 14.2508 - val_loss: 203.0843
# Epoch 47/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.6401 - loss: 244.6379 - val_RootMeanSquaredError: 13.9422 - val_loss: 194.3856
# Epoch 48/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - RootMeanSquaredError: 15.7125 - loss: 246.9286 - val_RootMeanSquaredError: 14.1675 - val_loss: 200.7190
# Epoch 49/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - RootMeanSquaredError: 15.5641 - loss: 242.2556 - val_RootMeanSquaredError: 14.0777 - val_loss: 198.1818
# Epoch 50/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - RootMeanSquaredError: 15.5983 - loss: 243.3253 - val_RootMeanSquaredError: 14.6716 - val_loss: 215.2560
# Epoch 51/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.5373 - loss: 241.4451 - val_RootMeanSquaredError: 14.2378 - val_loss: 202.7149
# Epoch 52/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.5495 - loss: 241.8233 - val_RootMeanSquaredError: 14.2600 - val_loss: 203.3484
# Epoch 53/100
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - RootMeanSquaredError: 15.5464 - loss: 241.7355 - val_RootMeanSquaredError: 14.0364 - val_loss: 197.0205

# %%
# Validation
predictions = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
r2 = r2_score(y_test, predictions)
print(f"ANN RMSE: {rmse}")
print(f"ANN R2: {r2}")
# Out:
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# ANN RMSE: 13.93934351322528
# ANN R2: 0.7399151482965942
